# %% [markdown]
# # Simulating Gate Noise

# %% [markdown]
# ## Pure states vs. mixed states
#
# Errors in quantum computing can introduce classical uncertainty in what the underlying state is.
# When this happens we sometimes need to consider not only wavefunctions but also probabilistic sums of
# wavefunctions when we are uncertain as to which one we have. For example, if we think that an X gate
# was accidentally applied to a qubit with a 50-50 chance then we would say that there is a 50% chance
# we have the $\ket{0}$ state and a 50% chance that we have a $\ket{1}$ state.
# This is called an "impure" or
# "mixed"state in that it isn't just a wavefunction (which is pure) but instead a distribution over
# wavefunctions. We describe this with something called a density matrix, which is generally an
# operator. Pure states have very simple density matrices that we can write as an outer product of a
# ket vector $\ket{\psi}$ with its own bra version $\bra{\psi}=\ket{\psi}^\dagger$.
# For a pure state the density matrix is simply
#
#
# $$
#    \rho_\psi = \ket{\psi}\bra{\psi}.
# $$
# The expectation value of an operator for a mixed state is given by
#
# $$
#    \langle X \rangle_\rho = Tr({X \rho})
# $$
# where $Tr(A)$ is the trace of an operator, which is the sum of its diagonal elements
# which is independent of choice of basis.
# Pure state density matrices satisfy
#
# $$
#    \rho \text{ is pure } \Leftrightarrow \rho^2 = \rho
# $$
# which you can easily verify for $\rho_\psi$ assuming that the state is normalized.
# If we want to describe a situation with classical uncertainty between states $\rho_1$ and
# $\rho_2$, then we can take their weighted sum
# $$
#    \rho = p \rho_1 + (1-p) \rho_2
# $$
# where $p\in [0,1]$ gives the classical probability that the state is $\rho_1$.
#
# Note that classical uncertainty in the wavefunction is markedly different from superpositions.
# We can represent superpositions using wavefunctions, but use density matrices to describe
# distributions over wavefunctions. You can read more about density matrices [here](https://en.wikipedia.org/wiki/Density_matrix).

# %% [markdown]
# # Quantum gate errors
# ## What are they?
# For a quantum gate given by its unitary operator $U$, a "quantum gate error" describes the scenario in which the actually induces transformation deviates from $\ket{\psi} \mapsto U\ket{\psi}$.
# There are two basic types of quantum gate errors:
#
# 1. **coherent errors** are those that preserve the purity of the input state, i.e., instead of the above mapping we carry out a perturbed, but unitary operation $\ket{\psi} \mapsto \tilde{U}\ket{\psi}$, where $\tilde{U} \neq U$.
# 2. **incoherent errors** are those that do not preserve the purity of the input state,
#     in this case we must actually represent the evolution in terms of density matrices.
#     The state $\rho := \ket{\psi}\bra{\psi}$ is then mapped as
#     $$
#     \rho \mapsto \sum_{j=1}^n K_j\rho K_j^\dagger,
#     $$
#     where the operators $\{K_1, K_2, \dots, K_m\}$ are called Kraus operators and must obey
#     $\sum_{j=1}^m K_j^\dagger K_j = I$ to conserve the trace of $\rho$.
#     Maps expressed in the above form are called Kraus maps. It can be shown that every physical map on a finite
#     dimensional quantum system can be represented as a Kraus map, though this representation is not generally unique.
#     [You can find more information about quantum operations here](https://en.wikipedia.org/wiki/Quantum_operation#Kraus_operators)
#
# In a way, coherent errors are *in principle* amendable by more precisely calibrated control. Incoherent errors are more tricky.

# %% [markdown]
# ## Why do incoherent errors happen?
# When a quantum system (e.g., the qubits on a quantum processor) is not perfectly isolated from its environment it generally co-evolves with the degrees of freedom it couples to. The implication is that while the total time evolution of system and environment can be assumed to be unitary, restriction to the system state generally is not.
#
# **Let's throw some math at this for clarity:**
# Let our total Hilbert space be given by the tensor product of system and environment Hilbert spaces:
# $\mathcal{H} = \mathcal{H}_S \otimes \mathcal{H}_E$.
# Our system "not being perfectly isolated" must be translated to the statement that the global Hamiltonian contains a contribution that couples the system and environment:
# $$
# H = H_S \otimes I + I \otimes H_E + V
# $$
# where $V$ non-trivally acts on both the system and the environment.
# Consequently, even if we started in an initial state that factorized over system and environment $\ket{\psi}_{S,0}\otimes \ket{\psi}_{E,0}$
# if everything evolves by the Schrödinger equation
# $$
# \ket{\psi_t} = e^{-i \frac{Ht}{\hbar}} \left(\ket{\psi}_{S,0}\otimes \ket{\psi}_{E,0}\right)
# $$
# the final state will generally not admit such a factorization.

# %% [markdown]
# ## A toy model
# **In this (somewhat technical) section we show how environment interaction can corrupt an identity gate and derive its Kraus map.**
# For simplicity, let us assume that we are in a reference frame in which both the system and environment Hamiltonian's vanish $H_S = 0, H_E = 0$ and where the cross-coupling is small even when multiplied by the duration of the time evolution $\|\frac{tV}{\hbar}\|^2 \sim \epsilon \ll 1$ (any operator norm $\|\cdot\|$ will do here).
# Let us further assume that $V = \sqrt{\epsilon} V_S \otimes V_E$ (the more general case is given by a sum of such terms) and that
# the initial environment state satisfies $\bra{\psi}_{E,0} V_E\ket{\psi}_{E,0} = 0$. This turns out to be a very reasonable assumption in practice but a more thorough discussion exceeds our scope.
#
# Then the joint system + environment state $\rho = \rho_{S,0} \otimes \rho_{E,0}$ (now written as a density matrix) evolves as
# $$
# \rho \mapsto \rho' :=  e^{-i \frac{Vt}{\hbar}} \rho e^{+i \frac{Vt}{\hbar}}
# $$
# Using the Baker-Campbell-Hausdorff theorem we can expand this to second order in $\epsilon$
# $$
# \rho' = \rho - \frac{it}{\hbar} [V, \rho] - \frac{t^2}{2\hbar^2} [V, [V, \rho]] + O(\epsilon^{3/2})
# $$
# We can insert the initially factorizable state $\rho = \rho_{S,0} \otimes \rho_{E,0}$ and trace over the environmental degrees of freedom to obtain
# \begin{align}
# \rho_S' := \tr_E \rho' & = \rho_{S,0}  \underbrace{\tr \rho_{E,0}}_{1} - \frac{i\sqrt{\epsilon} t}{\hbar} \underbrace{\left[ V_S \rho_{S,0} \underbrace{\tr V_E\rho_{E,0}}_{\bra{\psi}_{E,0} V_E\ket{\psi}_{E,0} = 0} - \rho_{S,0}V_S  \underbrace{\tr \rho_{E,0}V_E}_{\bra{\psi}_{E,0} V_E\ket{\psi}_{E,0} = 0} \right]}_0 \\
# & \qquad - \frac{\epsilon t^2}{2\hbar^2} \left[ V_S^2\rho_{S,0}\tr V_E^2 \rho_{E,0} + \rho_{S,0} V_S^2 \tr \rho_{E,0}V_E^2 - 2 V_S\rho_{S,0}V_S\tr V_E \rho_{E,0}V_E\right] \\
# & = \rho_{S,0} - \frac{\gamma}{2} \left[ V_S^2\rho_{S,0} + \rho_{S,0} V_S^2  - 2 V_S\rho_{S,0}V_S\right]
# \end{align}
# where the coefficient in front of the second part is by our initial assumption very small $\gamma := \frac{\epsilon t^2}{2\hbar^2}\tr V_E^2 \rho_{E,0} \ll 1$.
# This evolution happens to be approximately equal to a Kraus map with operators $K_1 := I - \frac{\gamma}{2} V_S^2, K_2:= \sqrt{\gamma} V_S$:
# \begin{align}
# \rho_S \to \rho_S' &= K_1\rho K_1^\dagger + K_2\rho K_2^\dagger
#  = \rho - \frac{\gamma}{2}\left[ V_S^2 \rho + \rho V_S^2\right] + \gamma V_S\rho_S V_S + O(\gamma^2)
# \end{align}
# This agrees to $O(\epsilon^{3/2})$ with the result of our derivation above. This type of derivation can be extended to many other cases with little complication and a very similar argument is used to derive the [Lindblad master equation](https://en.wikipedia.org/wiki/Lindblad_equation).

# %% [markdown]
# # Support for noisy gates on the Rigetti QVM
#
# As of today, users of our Forest API can annotate their QUIL programs by certain pragma statements that inform the QVM that a particular gate on specific target qubits should be replaced by an imperfect realization given by a Kraus map.
#
# The QVM propagates **pure states** — so how does it simulate noisy gates? It does so by yielding the correct outcomes **in the average over many executions of the QUIL program**:
# When the noisy version of a gate should be applied the QVM makes a random choice which Kraus operator is applied to the current state with a probability that ensures that the average over many executions is equivalent to the Kraus map.
# In particular, a particular Kraus operator $K_j$ is applied to $\ket{\psi}_S$
# $$
# \ket{\psi'}_S = \frac{1}{\sqrt{p_j}} K_j \ket{\psi}_S
# $$
# with probability $p_j:= \bra{\psi}_S K_j^\dagger K_j \ket{\psi}_S$.
# In the average over many execution $N \gg 1$ we therefore find that
# \begin{align}
# \overline{\rho_S'} & = \frac{1}{N} \sum_{n=1}^N \ket{\psi'_n}_S\bra{\psi'_n}_S \\
# & = \frac{1}{N} \sum_{n=1}^N p_{j_n}^{-1}K_{j_n}\ket{\psi}_S \bra{\psi}_SK_{j_n}^\dagger
# \end{align}
# where $j_n$ is the chosen Kraus operator label in the $n$-th trial.
# This is clearly a Kraus map itself! And we can group identical terms and rewrite it as
# \begin{align}
# \overline{\rho_S'} & =
#   \sum_{\ell=1}^n \frac{N_\ell}{N}  p_{\ell}^{-1}K_{\ell}\ket{\psi}_S \bra{\psi}_SK_{\ell}^\dagger
# \end{align}
# where $N_{\ell}$ is the number of times that Kraus operator label $\ell$ was selected.
# For large enough $N$ we know that $N_{\ell} \approx N p_\ell$ and therefore
# \begin{align}
# \overline{\rho_S'} \approx \sum_{\ell=1}^n K_{\ell}\ket{\psi}_S \bra{\psi}_SK_{\ell}^\dagger
# \end{align}
# which proves our claim.
# **The consequence is that noisy gate simulations must generally be repeated many times to obtain representative results**.

# %% [markdown]
# # Noisy simulator for pyquil
#
# The module new_noise.py facilitates the execution of a realistic simulation of a noisy quantum computer, providing users with an accessible and robust tool. The core functionality emulates Rigetti's quantum computers, utilizing current calibration data from the company. Additionally, users have the ability to explore the effects of varying noise intensity or specifying alternative noise parameters.
#
# In the following sections, we will delve into the workings of the simulator, along with a comprehensive guide on its usage, accompanied by illustrative examples.

# %% [markdown]
# ## How does the simulator work?
#
# The simulator employs Kraus operators as its foundation, as described previously. However, instead of incorporating Kraus operators directly into the gate (which poses challenges for parametric gates and does not account for effects on other qubits), we apply them to unity matrices following each gate. This serves as the fundamental concept behind the simulator.
#
# It is important to note that the majority of gates utilized in quantum programs are not physically realized within the quantum computer. Instead, they are implemented using a limited set of native gates. For instance, in Rigetti's Aspen-M-3 computer, the native gates include RX, RZ, CZ, CPHASE, and XY. To accurately simulate the real computer, the simulator, by default, translates the program into native gates and subsequently introduces noise into the native program, unless the user specifies otherwise.
#
# ### Depolarizing
#
# Upon the application of a gate to a qubit, some quantum information may be lost, resulting in the density matrix representing the qubit being mapped to a linear combination of itself and a maximally mixed state. For each qubit and gate, the fidelity is known, which is the probability of the qubit remaining consistent.
#
# The corresponding Kraus operators (with $\lambda = 1 - \text{fidelity}$) are as follows:
#
# $$
# K_0 = \sqrt{1- \frac{3 \lambda}{4}}I
# $$
# $$
# K_1 = \sqrt{\frac{\lambda}{4}} \sigma_X
# $$
# $$
# K_2 = \sqrt{\frac{\lambda}{4}} \sigma_Y
# $$
# $$
# K_3 = \sqrt{\frac{\lambda}{4}} \sigma_Z
# $$
#
# [For further information on quantum depolarizing channels, please refer to this.](https://en.wikipedia.org/wiki/Quantum_depolarizing_channel)
#
# After each gate, the depolarizing channel is applied to the target qubits. Although there is a probability, dictated by the fidelity, that nothing will occur, there remains the possibility that the qubit will transition into a maximally mixed state.
#
# ### Decoherence
#
# Each gate possesses a specific duration time. Within this module, we assume that the duration of a two-qubit gate is 176 nanoseconds, while the duration of a one-qubit gate is 32 nanoseconds.
#
# During the application of a two-qubit gate, other gates are typically not applied to the additional qubits involved in the program. However, these qubits do experience a waiting period and are subject to decoherence noise: damping and dephasing. The Kraus operators representing damping and dephasing are determined by the times T1 and T2; longer times indicate lower noise levels for the qubit. Consequently, after each two-qubit gate in the program, we introduce noise intensity gates (for damping and dephasing) to all other qubits in the program.
#
# One-qubit gates are presumed to be applied simultaneously, so by default, we do not apply decoherence noise (representing waiting) to qubits not participating in the gate. This default setting can be altered as needed.
#
# Amplitude **damping** channels are imperfect identity maps with Kraus operators
# $$
# K_1 = \begin{pmatrix}
# 1 & 0 \\
# 0 & \sqrt{1-p}
# \end{pmatrix} \\
# K_2 = \begin{pmatrix}
# 0 & \sqrt{p} \\
# 0 & 0
# \end{pmatrix}
# $$
# Here, $p$ represents the probability that a qubit in the $\ket{1}$ state decays to the $\ket{0}$ state, and it is given by $p = 1 - \exp(-T_{\rm gate}/T_1)$.
#
# **Dephasing** is usually characterized through a qubit's $T_2$ time.
# For a single qubit the dephasing Kraus operators are
# $$
# K_1(p) = \sqrt{1-p} I_2 \\
# K_2(p) = \sqrt{p} \sigma_Z
# $$
# In this case, $p = 0.5 * (1 - exp(-(\frac{\text{gate_time}}{T_2} - \frac{\text{gate_time}}{2 \cdot T_1})))$ denotes the probability that the qubit is dephased over the time interval of interest, $I_2$ is the $2\times 2$-identity matrix, and $\sigma_Z$ is the Pauli-Z operator.
#
# These two sets of Kraus operators are combined to simulate damping after dephasing, resulting in decoherence noise.
#
# ### Readout
#
# The final category of noise, readout noise, is distinct from the previously discussed types. For each qubit, the readout fidelity is known, which is the probability that the read value is accurate. This probability is assumed to be identical for obtaining 0 when the qubit is in state 0 and acquiring 1 when the qubit is in state 1.
#
# The QVM is capable of handling a Pragma that incorporates readout noise. Therefore, the Pyquil module only needs to construct the appropriate Pragma according to the corresponding fidelities.

# %% [markdown]
# ## Usage
#
# ### Basic usage
#
# Utilizing the simulator is straightforward: First, create a quantum computer object and a program, and then provide them as parameters to the function. The output will be a noisy version of the program, simulating the real quantum computer specified as an input. The process can be summarized as follows:

# %%
from pyquil.quil import Program
from pyquil.api import get_qc
from new_noise import add_noise_to_program


# create a Quantum computer object:
qc = get_qc('Aspen-M-3', as_qvm=True)
# create a program:
prog = Program()
# write your quantum program...

# get the noisy version of your program, fitted to the quantum computer you chose:
noisy_prog = add_noise_to_program(qc=qc, p=prog)

# %% [markdown]
# ### Advanced usage
#
# Certain users may not only wish to evaluate the behavior of their program on a real Rigetti quantum computer, but also explore the effects of varying noise levels or the resolution of specific noise types. Some users might want to define their own fidelities and decoherence times, while others may be interested in investigating different gate types with new estimated noise parameters. For these users, the basic function can be further customized and adapted to accommodate a wide range of requirements.
#
# #### **convert to native gates:**
#
# As previously discussed, the function's default behavior is to convert the program into native gates before introducing noise. However, this approach may be problematic in two scenarios:
#
# If a user has already written their program using native gates and desires them to execute exactly as written (without altering the qubits or optimizing the program), the default compiler may modify their choices.
# If a user wishes to explore the potential of non-native gates, accompanied by their own estimated noise parameters, the default function will convert these gates into native ones, defeating the purpose.
# In such instances, the solution is to instruct the function not to convert the program into native gates. This can be achieved with the following command:
#
# `noisy_prog = add_noise_to_program(qc=qc, p=prog, convert_to_native=False)`
#
# #### **intensity parameter:**
#
# You can assess the impact of noise on your program by adjusting the noise intensity. The default value is 1, which corresponds to the noise level in a real quantum computer. This parameter can be varied from 0 (no noise) to infinity (extremely noisy). For example, to reduce the noise intensity to 0.5, proceed as follows:
# `noisy_prog = add_noise_to_program(qc=qc, p=prog, noise_intensity=0.5)`
#
# #### **Setting noise types:**
#
# You can also configure the types of noise you want to introduce to the program. As previously mentioned, the default assumption is that two-qubit gates operate independently, while one-qubit gates run simultaneously. This assumption may not hold true for different types of programs, so users can modify the settings accordingly. If single-qubit gates do not operate simultaneously, you can add decoherence noise to all other qubits in the program while the one-qubit gate is being applied, effectively simulating the waiting process for the remaining qubits:
#
# `noisy_prog = add_noise_to_program(qc=qc, p=prog, single_q_noise_after_1q_gate=True)`
#
# Conversely, if your two-qubit gates operate simultaneously, you can eliminate the waiting noise following the execution of two-qubit gates:
# `noisy_prog = add_noise_to_program(qc=qc, p=prog, single_q_noise_after_2q_gate=False)`
#
# Additionally, you have the option to exclude readout noise, depolarizing noise, or any combination thereof:
# `noisy_prog = add_noise_to_program(qc=qc, p=prog, readout_noise=False, depolarizing=False)`
#
# When depolarizing noise is enabled, the target qubit does not receive additional decoherence "waiting" noise, as it is already incorporated within the depolarizing noise. If you choose to disable depolarizing noise, the target qubit, along with all other qubits in the program, will still be subject to decoherence noise based on the parameters `single_q_noise_after_1q_gate` and `single_q_noise_after_2q_gate`. You can also configure the target qubit to receive decoherence noise according to the gate time, as demonstrated below:
#
# `noisy_prog = add_noise_to_program(qc=qc, p=prog, depolarizing=False, single_q_noise_after_2q_gate=False, single_q_noise_only_on_targets=True)`

# %% [markdown]
# #### **Calibrations**
#
# When selecting a quantum computer object and providing it to the function, its calibrations are stored in a class called `Calibrations`. Each noise type is stored as a dictionary that maps a qubit to its fidelity or time (depending on the noise type). The dictionaries include: T1, T2, readout_fidelity, and fidelities - which is a nested dictionary for each gate. The class also contains a set of two-qubit gates present in the computer.
#
# In a basic usage of the function, the quantum computer's name is provided, and the appropriate calibrations for the specified computer are retrieved from the web. (A future improvement could involve obtaining this information directly, without relying on a specific URL and JSON format).
#
# Often, you may want to run a loop to test your program with various modifications on the same computer. In such cases, constructing the Calibration instance from the web can be inefficient. A better practice would be to create the instance explicitly once and pass it as a parameter to the function:
#
# `cal = Calibrations('Aspen-M-3')`
#
# `noisy_prog = add_noise_to_program(qc, prog, calibrations=cal)`
#
# If you want to define custom noise parameters or gate types, you should create an instance of `Calibrations`, populate it with your own data, and then provide it as a parameter to the function:

# %%
from new_noise import Calibrations

cal = Calibrations()
cal.T1 = {0: 1.6e-5, 1: 5.1e-6}
cal.T2 = {0: 7.6e-6, 1: 9.3e-6}
cal.two_q_gates = set(['XY'])
cal.readout_fidelity = {0: 0.994, 1: 0.984}
# attention: in "fidelities" (and only there), the qubit indeces are strings, not integers.
cal.fidelities["1Q_gate"] = {'0': 0.999, '1': 0.998}
cal.fidelities["XY"] = {'0-1': 0.977}

noisy_prog = add_noise_to_program(qc, prog, calibrations=cal)

# %% [markdown]
# ## Example: GHZ
#
# In a GHZ state, three qubits are entangled, and the measurement results should ideally be half '000' and half '111'. The Greenberger-Horne-Zeilinger (GHZ) experiment is an important demonstration of quantum entanglement involving three or more qubits. This entangled state is highly sensitive to noise and decoherence, making it an ideal testbed for evaluating the performance of quantum computers and error mitigation techniques.
#
# The GHZ experiment can be implemented using the following sequence of quantum gates:
#
# Apply a Hadamard gate (H) to the first qubit, which puts it in an equal superposition of '0' and '1' states.
# Apply a CNOT gate between the first and second qubits, creating entanglement between them.
# Apply another CNOT gate between the second and third qubits, resulting in the entanglement of all three qubits.
# After performing these operations, the resulting GHZ state is $(\ket{000} + \ket{111})/\sqrt{2}$. Due to noise, the actual program will yield other results as well. In this example, we examine the results for a noise-free program, as well as the outcomes for a noisy program that simulates a run on Rigetti's Aspen-M-2 computer. Furthermore, we investigate what would have occurred if all noise levels were reduced to half of their actual values. By examining the outcomes of the GHZ experiment in the presence of different noise levels, researchers can gain insights into the behavior of quantum computers under various conditions and investigate strategies for improving their performance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from pyquil.quil import Program
from pyquil.gates import H, MEASURE, CNOT
from pyquil.api import get_qc
from new_noise import add_noise_to_program, Calibrations
import matplotlib.pyplot as plt

def ghz(qc, qubits, numshots, noise=False, cal=None, intensity=1.0):
    p = Program()
    p.declare("ro", "BIT", 3)
    p += H(qubits[0])
    p += CNOT(qubits[0], qubits[1])
    p += CNOT(qubits[1], qubits[2])
    p += MEASURE(qubits[0], ("ro", 0))
    p += MEASURE(qubits[1], ("ro", 1))
    p += MEASURE(qubits[2], ("ro", 2))
    p.wrap_in_numshots_loop(numshots)
    if noise:
        if cal is not None:
            p = add_noise_to_program(qc, p, calibrations=cal, noise_intensity=intensity)
        else:
            p = add_noise_to_program(qc, p, noise_intensity=intensity)
    return p

def run_experiment(qpu, qubits, numshots):
    qvm = get_qc(qpu, as_qvm=True, execution_timeout=1000)
    cal = Calibrations(qvm)
    no_noise = qvm.run(ghz(qvm,qubits,numshots, False)).readout_data.get("ro")
    half_noise = qvm.run(ghz(qvm,qubits,numshots, True, cal, intensity=0.5)).readout_data.get("ro")
    noisy = qvm.run(ghz(qvm,qubits,numshots, True, cal)).readout_data.get("ro")
    return no_noise, half_noise, noisy

def plot_results(results, label):
    histogram={}
    for i in results:
        code=("00"+str(int(float(i[2])*100+float(i[1])*10+float(i[0]))))[-3:]
        histogram[code]=histogram.get(code,0)+1
    histogram=dict(sorted(histogram.items()))
    plt.bar(*zip(*histogram.items()), label=label)
    plt.xlabel('State')
    plt.ylabel('Counts')
    plt.legend()
    plt.show()

no_noise, half_noise, noisy = run_experiment('Aspen-M-3',[0,1,2], 1000)
plot_results(no_noise, 'no noise')
plot_results(half_noise, 'half noise')
plot_results(noisy, 'noisy')

# %%
from pyquil.quantum_processor.qcs import get_qcs_quantum_processor

qpu = get_qcs_quantum_processor("Aspen-M-3")

isa = qpu.to_compiler_isa()

isa.edges
# Out:
# {'0-1': Edge(ids=[0, 1], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9027399278265438, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.896052377636963, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9708951030061732, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '100-101': Edge(ids=[100, 101], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9702240389373302, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9610987941358826, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9507827643436645, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '10-11': Edge(ids=[10, 11], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9908811888353015, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9722510602784272, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9829211368666912, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '110-111': Edge(ids=[110, 111], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9398276287769746, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9072241675361732, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8783318649448798, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '20-21': Edge(ids=[20, 21], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9066799371047568, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7692750018781291, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9756280601633356, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '120-121': Edge(ids=[120, 121], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9871451770089947, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9817546050667364, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9806567479284989, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '30-31': Edge(ids=[30, 31], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9671792270939272, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8420700144416194, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9772675792757834, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '130-131': Edge(ids=[130, 131], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9778530810227215, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '40-41': Edge(ids=[40, 41], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8842489178776117, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9009224953313134, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.905091128150425, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '140-141': Edge(ids=[140, 141], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9549742534647117, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9442235100863661, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.989547584404782, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '1-2': Edge(ids=[1, 2], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8771756586120729, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8470557036251354, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.808948505062648, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '101-102': Edge(ids=[101, 102], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9497142455652091, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '11-12': Edge(ids=[11, 12], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9730861240561732, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.916813571788427, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9720773580063253, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '111-112': Edge(ids=[111, 112], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9367656435701974, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.886056792145041, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9703758614578872, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '21-22': Edge(ids=[21, 22], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8913732648051503, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.816551174059224, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8877780802043967, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '121-122': Edge(ids=[121, 122], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9068328459771676, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8648689792028805, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8598660214652786, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '31-32': Edge(ids=[31, 32], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9690008518652098, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9625039398760326, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.958038966914671, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '131-132': Edge(ids=[131, 132], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8021921824538422, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8331222110957351, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.91530683241176, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '41-42': Edge(ids=[41, 42], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9869900169190005, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9776846543459089, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9769613614465077, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '141-142': Edge(ids=[141, 142], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8327081870121646, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.6922382658216129, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8274071130494804, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '2-3': Edge(ids=[2, 3], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.812463197883151, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7940583800863831, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8560441641480752, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '102-103': Edge(ids=[102, 103], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9025846354261132, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9585704058480415, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9524682350291235, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '12-13': Edge(ids=[12, 13], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9801981378154736, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9631384818690872, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9724320529269935, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '112-113': Edge(ids=[112, 113], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8262744333601155, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7694973649891498, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8094696685392678, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '22-23': Edge(ids=[22, 23], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8576355397728037, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7912760332690802, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8039493154622044, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '122-123': Edge(ids=[122, 123], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8694614994210794, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8012900906432714, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9230727033889701, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '32-33': Edge(ids=[32, 33], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9683951056117759, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9610890228853536, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9609230635812768, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '132-133': Edge(ids=[132, 133], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9466377375007196, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8447186786518741, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8228443156204502, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '42-43': Edge(ids=[42, 43], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8778010797207308, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8641025513884817, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9768819809780276, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '142-143': Edge(ids=[142, 143], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.6831256273099254, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8116142762948136, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.7961451408633047, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '3-4': Edge(ids=[3, 4], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9197351116181519, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.902595861877397, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9535216867096371, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '103-104': Edge(ids=[103, 104], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9846382337823403, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9610521071845259, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9579917873316852, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '13-14': Edge(ids=[13, 14], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9602669122876941, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8846084106383372, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9206576467511369, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '113-114': Edge(ids=[113, 114], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8283100131956802, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8409784020967969, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8227809011598594, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '23-24': Edge(ids=[23, 24], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8264512663481299, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8036908954558932, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8461694738929662, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '123-124': Edge(ids=[123, 124], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8143522647114658, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.867207118903425, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9784361382296746, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '33-34': Edge(ids=[33, 34], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.980761660146068, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9639600769285828, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9822194536170666, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '133-134': Edge(ids=[133, 134], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9012712501137834, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8677367360313559, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9504534804786828, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '43-44': Edge(ids=[43, 44], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8197407294542218, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7742981476368755, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8929829017791907, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '143-144': Edge(ids=[143, 144], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9301859774618042, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8900753616594372, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.95045121477848, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '4-5': Edge(ids=[4, 5], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9642094287393962, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8931743875481084, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9041062937046828, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '104-105': Edge(ids=[104, 105], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.7658539450649055, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.797069038726801, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8013525670769691, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '14-15': Edge(ids=[14, 15], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9473858447882322, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9746739831496722, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '114-115': Edge(ids=[114, 115], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8298619783494694, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8016422052456896, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9609672692435531, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '24-25': Edge(ids=[24, 25], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.843445755395812, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7911457577773754, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.858773995041791, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '124-125': Edge(ids=[124, 125], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9540893408651495, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8209442553055052, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9600919197760046, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '34-35': Edge(ids=[34, 35], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9741210650418566, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9875578518405631, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9680568415438189, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '134-135': Edge(ids=[134, 135], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9495402926258517, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8974392838289844, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.983072967598561, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '44-45': Edge(ids=[44, 45], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8381774614189371, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8048966733743887, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8262113870101715, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '144-145': Edge(ids=[144, 145], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9578017359252426, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9539616358275032, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9611899019314665, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '5-6': Edge(ids=[5, 6], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9685183303711047, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9626815343117241, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.7586526045331091, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '105-106': Edge(ids=[105, 106], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.7721797160717062, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '15-16': Edge(ids=[15, 16], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9468923857419281, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '115-116': Edge(ids=[115, 116], dead=True, gates=[]),
#  '25-26': Edge(ids=[25, 26], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.815094383010696, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7873985598262078, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '125-126': Edge(ids=[125, 126], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9205248022630201, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '35-36': Edge(ids=[35, 36], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9094431726029063, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.929365835506107, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9750343799991693, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '135-136': Edge(ids=[135, 136], dead=True, gates=[]),
#  '45-46': Edge(ids=[45, 46], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8126236676267777, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.675614219464888, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.5000877776833278, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '145-146': Edge(ids=[145, 146], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9582901715402573, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9603298228355119, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.830512200815525, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '6-7': Edge(ids=[6, 7], dead=True, gates=[]),
#  '106-107': Edge(ids=[106, 107], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9757244612985397, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9444413550330775, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9759954462604843, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '16-17': Edge(ids=[16, 17], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.7903320534753724, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8349160196510943, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8856924845076695, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '116-117': Edge(ids=[116, 117], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.8481789231833846, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '26-27': Edge(ids=[26, 27], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8156916587597322, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8814187329418266, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9866810106182069, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '126-127': Edge(ids=[126, 127], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8998070321203124, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8662586296167312, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.911828107563425, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '36-37': Edge(ids=[36, 37], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9736550622250728, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9683316084692574, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9734189757679446, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '136-137': Edge(ids=[136, 137], dead=True, gates=[]),
#  '46-47': Edge(ids=[46, 47], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.8149047655533017, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '146-147': Edge(ids=[146, 147], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9019544618122454, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8471739494271556, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8358752380265247, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '0-7': Edge(ids=[0, 7], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9493071650645394, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8986004351022062, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '100-107': Edge(ids=[100, 107], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9671002681562813, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9648655623933773, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9765668691109599, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '10-17': Edge(ids=[10, 17], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9787366661359239, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.948296030451483, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9769367480911746, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '110-117': Edge(ids=[110, 117], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8785125092167176, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8077138183621041, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9601678553856707, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '20-27': Edge(ids=[20, 27], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8170195550895799, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8460266664101291, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8499589418368675, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '120-127': Edge(ids=[120, 127], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9247602314757999, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9633778028838487, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9884493222155756, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '30-37': Edge(ids=[30, 37], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9795253458740316, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9531871892652994, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9832599535822211, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '130-137': Edge(ids=[130, 137], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9442549973600637, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9651897360693105, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9805338533529782, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '40-47': Edge(ids=[40, 47], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9464006269938059, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '140-147': Edge(ids=[140, 147], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9826375478824173, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9115476732463386, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9725964928590529, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '2-15': Edge(ids=[2, 15], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.8127364230194494, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '102-115': Edge(ids=[102, 115], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8588218408886447, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9742343134437728, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9821317015867518, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '12-25': Edge(ids=[12, 25], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8694387286820644, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8576197966558429, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9488075594433836, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '112-125': Edge(ids=[112, 125], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8844864909965738, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8519817880295615, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8396829404245678, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '22-35': Edge(ids=[22, 35], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.969241839849111, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8196242619757357, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '122-135': Edge(ids=[122, 135], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9065565078047609, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.888924729666259, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8816034545965071, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '32-45': Edge(ids=[32, 45], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.855864385163127, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.6302950720341147, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8327679293780484, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '132-145': Edge(ids=[132, 145], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9372872331449655, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8503402143937674, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8995705532791508, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '1-16': Edge(ids=[1, 16], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9393816497085126, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.9691827766420773, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9639578075046057, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '101-116': Edge(ids=[101, 116], dead=True, gates=[]),
#  '11-26': Edge(ids=[11, 26], dead=True, gates=[]),
#  '111-126': Edge(ids=[111, 126], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8554464918912728, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8172434829423496, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8480622545675182, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '21-36': Edge(ids=[21, 36], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9201268745034757, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8953767857637024, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9034252883039133, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '121-136': Edge(ids=[121, 136], dead=True, gates=[]),
#  '31-46': Edge(ids=[31, 46], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8256585380500107, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7916638596894682, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8287056978775705, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '131-146': Edge(ids=[131, 146], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9664001360982577, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '7-104': Edge(ids=[7, 104], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9031299813242704, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.873964642657196, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9547651834108527, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '17-114': Edge(ids=[17, 114], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.835134655016179, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '27-124': Edge(ids=[27, 124], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8337667949719664, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.8352409322008101, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.7889642797104411, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '37-134': Edge(ids=[37, 134], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9653739165484123, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '47-144': Edge(ids=[47, 144], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.8527966306401207, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.7391513043090745, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.840041975248917, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '0-103': Edge(ids=[0, 103], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.9678144162721874, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.952160525795824, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.9543154317905855, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '10-113': Edge(ids=[10, 113], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.832438847674951, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.6666823500951149, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.8142948796472712, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '20-123': Edge(ids=[20, 123], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9876563420825102, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '30-133': Edge(ids=[30, 133], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.96766091916868, parameters=['theta'], arguments=['_', '_'], operator_type='gate')]),
#  '40-143': Edge(ids=[40, 143], dead=False, gates=[GateInfo(operator='CZ', duration=200.0, fidelity=0.96726313170522, parameters=[], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='CPHASE', duration=200.0, fidelity=0.825343350538141, parameters=['theta'], arguments=['_', '_'], operator_type='gate'), GateInfo(operator='XY', duration=200.0, fidelity=0.866687894464928, parameters=['theta'], arguments=['_', '_'], operator_type='gate')])}

# %%
isa.edges.get("20-123")
# Out:
# Edge(ids=[20, 123], dead=False, gates=[GateInfo(operator='XY', duration=200.0, fidelity=0.9876563420825102, parameters=['theta'], arguments=['_', '_'], operator_type='gate')])

# %%
from typing import Dict, Optional, Self
from pyquil.api import QuantumComputer

def get_t1s( qpu) -> Dict[int, float]:
    benchmarks = qpu._isa.benchmarks
    operations = next(operation for operation in benchmarks if operation.name == "FreeInversionRecovery")
    t1s = {site.node_ids[0]: site.characteristics[0].value for site in operations.sites}
    return t1s


def get_t2s(qpu) -> Dict[int, float]:
    benchmarks = qpu._isa.benchmarks
    operations = next(operation for operation in benchmarks if operation.name == "FreeInductionDecay")
    t2s = {site.node_ids[0]: site.characteristics[0].value for site in operations.sites}
    return t2s

def get_1q_fidelities(qpu) -> Dict[int, float]:
    benchmarks = qpu._isa.benchmarks
    operations = next(operation for operation in benchmarks if operation.name == 'randomized_benchmark_1q')
    fidelities = {site.node_ids[0]: site.characteristics[0].value for site in operations.sites}
    return fidelities

def get_readout_fidelities(qpu) -> Dict[int, float]:
    fidelity_dict = {}
    isa = qpu.to_compiler_isa()
    qubits = isa.qubits
    for key, qubit in qubits.items():
        for gate in qubit.gates:
            if hasattr(gate, 'operator') and gate.operator == 'MEASURE':
                fidelity_dict[int(key)] = gate.fidelity
                break  # Assuming there's only one measure fidelity per qubit
    return fidelity_dict

class Calibrations:
    """
    encapsulate the calibration data for Aspen-M-2 or Aspen-M-3 machine.

        contains:
                T1
                T2
                fidelities: 1Q_gate, and a dict for each 2Q gate
                readout

    args: qc (QuantumComputer, optional): a Quantum Computer (Aspen-M-2 or Aspen-M-3).
    Defaults to None, where the user can define their own calibration data.

        Notice: this class heavily relies on the specific way on which the lattices are written.
        this may change in time, and require changes in the class.
    """
    


    def __init__(self, qc: Optional[QuantumComputer] = None, calibrations: Self = None):
        self.fidelities = {}
        self.readout_fidelity = {}
        self.T2 = {}
        self.T1 = {}
        self.two_q_gates = set()

        if calibrations is not None:
            self.T1 = calibrations.T1.copy()
            self.T2 = calibrations.T2.copy()
            self.readout_fidelity = calibrations.readout_fidelity.copy()
            self.fidelities = {}
            for key, val in calibrations.fidelities.items():
                self.fidelities[key] = val.copy()
            self.two_q_gates = calibrations.two_q_gates
            return

        if qc is None:
            return  # user can set their own values

        else:
            name = qc.name if "qvm" not in qc.name else qc.name[:-4]
            qpu = get_qcs_quantum_processor(name)
            self.T1 = get_t1s(qpu)
            self.T2 = get_t2s(qpu)
            self.fidelities[Depolarizing_1Q_gate] = get_1q_fidelities(qpu)
            self.readout_fidelity = get_readout_fidelities(qpu)


    def _create_2q_dicts(self, qpu):
        pairs = self.calibrations["2Q"].keys()
        for gate in self.two_q_gates:
            fidelity = [
                self.calibrations["2Q"][pair].get("f" + gate, 1.0) for pair in pairs
            ]
            self.fidelities[gate] = dict(zip(pairs, fidelity))

# %%
qc = get_qc("Aspen-M-3", as_qvm=True, execution_timeout=1000)
name = qc.name if "qvm" not in qc.name else qc.name[:-4]
get_qcs_quantum_processor(name)
# Out:
# Aspen-M-3-qvm
# <QCSQuantumProcessor Aspen-M-3>
